# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns 
# %matplotlib inline

# %%
df = pd.read_json("user_info.json")

# %%
df
# Out:
#                         _id  index                                  guid  \
# 0  5c0a28d7a647437fd3d3a6aa      0  832f1af4-fb18-4ba8-b032-f4cbf343dbe9
# 1  5c0a28d780f6278b11586ab1      1  4306cb37-9506-48c2-8ccf-e69a063589ee
# 2  5c0a28d722e2e29d9bce2b64      2  5019e436-7cc4-48ee-a384-3483131f8ee1
# 3  5c0a28d76b5e8859a754cb4f      3  d2c4b1eb-2974-463a-b288-d1dae5dec187
# 4  5c0a28d7ebb99c08e2288c76      4  df0b59ed-2e81-43f1-9ae0-16f138e738be
# 5  5c0a28d749ce43912931715e      5  1d4dcbcd-c5b7-45a8-9650-82d7f98305c6
#
#    isActive    balance                    picture  age eyeColor  \
# 0     False  $3,806.93  http://placehold.it/32x32   20    green
# 1      True  $3,330.01  http://placehold.it/32x32   22    brown
# 2      True  $1,619.46  http://placehold.it/32x32   40    green
# 3     False  $3,334.12  http://placehold.it/32x32   29     blue
# 4     False  $1,368.48  http://placehold.it/32x32   33    brown
# 5      True  $2,441.66  http://placehold.it/32x32   23    green
#
# ...

# %%
df.head()
# Out:
#                         _id  index                                  guid  \
# 0  5c0a28d7a647437fd3d3a6aa      0  832f1af4-fb18-4ba8-b032-f4cbf343dbe9
# 1  5c0a28d780f6278b11586ab1      1  4306cb37-9506-48c2-8ccf-e69a063589ee
# 2  5c0a28d722e2e29d9bce2b64      2  5019e436-7cc4-48ee-a384-3483131f8ee1
# 3  5c0a28d76b5e8859a754cb4f      3  d2c4b1eb-2974-463a-b288-d1dae5dec187
# 4  5c0a28d7ebb99c08e2288c76      4  df0b59ed-2e81-43f1-9ae0-16f138e738be
#
#    isActive    balance                    picture  age eyeColor  \
# 0     False  $3,806.93  http://placehold.it/32x32   20    green
# 1      True  $3,330.01  http://placehold.it/32x32   22    brown
# 2      True  $1,619.46  http://placehold.it/32x32   40    green
# 3     False  $3,334.12  http://placehold.it/32x32   29     blue
# 4     False  $1,368.48  http://placehold.it/32x32   33    brown
#
#                  name  gender  ...              phone  \
# 0         Grace Berry  female  ...  +1 (814) 555-3298
# ...

# %%
df.shape
# Out:
# (6, 22)

# %%
df.tail()
# Out:
#                         _id  index                                  guid  \
# 1  5c0a28d780f6278b11586ab1      1  4306cb37-9506-48c2-8ccf-e69a063589ee
# 2  5c0a28d722e2e29d9bce2b64      2  5019e436-7cc4-48ee-a384-3483131f8ee1
# 3  5c0a28d76b5e8859a754cb4f      3  d2c4b1eb-2974-463a-b288-d1dae5dec187
# 4  5c0a28d7ebb99c08e2288c76      4  df0b59ed-2e81-43f1-9ae0-16f138e738be
# 5  5c0a28d749ce43912931715e      5  1d4dcbcd-c5b7-45a8-9650-82d7f98305c6
#
#    isActive    balance                    picture  age eyeColor  \
# 1      True  $3,330.01  http://placehold.it/32x32   22    brown
# 2      True  $1,619.46  http://placehold.it/32x32   40    green
# 3     False  $3,334.12  http://placehold.it/32x32   29     blue
# 4     False  $1,368.48  http://placehold.it/32x32   33    brown
# 5      True  $2,441.66  http://placehold.it/32x32   23    green
#
#                  name  gender  ...              phone  \
# 1      Hilary Sellers  female  ...  +1 (942) 536-3059
# ...

# %%
df.groupby('isActive')['_id'].count()
# Out:
# isActive
# False    3
# True     3
# Name: _id, dtype: int64

# %%
df.groupby('age')['_id'].count()
# Out:
# age
# 20    1
# 22    1
# 23    1
# 29    1
# 33    1
# 40    1
# Name: _id, dtype: int64

# %%
df.groupby('gender')['_id'].count()
# Out:
# gender
# female    3
# male      3
# Name: _id, dtype: int64

# %%
df.describe()
# Out:
#           index        age   latitude   longitude
# count  6.000000   6.000000   6.000000    6.000000
# mean   2.500000  27.833333 -14.933390   56.269483
# std    1.870829   7.678976  60.423544  118.411029
# min    0.000000  20.000000 -80.136744 -116.452211
# 25%    1.250000  22.250000 -65.079213  -26.253337
# 50%    2.500000  26.000000 -14.510225   90.216885
# 75%    3.750000  32.000000  37.693822  144.002834
# max    5.000000  40.000000  46.397226  176.780600

# %%
df[df['age']>34]
# Out:
#                         _id  index                                  guid  \
# 2  5c0a28d722e2e29d9bce2b64      2  5019e436-7cc4-48ee-a384-3483131f8ee1
#
#    isActive    balance                    picture  age eyeColor  \
# 2      True  $1,619.46  http://placehold.it/32x32   40    green
#
#              name  gender  ...              phone  \
# 2  Sherri Gilbert  female  ...  +1 (954) 591-2183
#
#                                    address  \
# 2  347 Seeley Street, Witmer, Kansas, 9369
#
#                                                about  \
# 2  Laborum ad excepteur amet sunt aliqua veniam c...
#
#                     registered   latitude   longitude  \
# 2  2014-10-31T05:02:03 -06:-30  34.404508 -116.452211
#
#                                                 tags  \
# 2  [adipisicing, cillum, deserunt, aute, ipsum, c...
#
#                                              friends  \
# 2  [{'id': 0, 'name': 'Sexton Watts'}, {'id': 1, ...
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   _id            6 non-null      object
#  1   index          6 non-null      int64
#  2   guid           6 non-null      object
#  3   isActive       6 non-null      bool
#  4   balance        6 non-null      object
#  5   picture        6 non-null      object
#  6   age            6 non-null      int64
#  7   eyeColor       6 non-null      object
#  8   name           6 non-null      object
#  9   gender         6 non-null      object
#  10  company        6 non-null      object
#  11  email          6 non-null      object
#  12  phone          6 non-null      object
#  13  address        6 non-null      object
#  14  about          6 non-null      object
#  15  registered     6 non-null      object
#  16  latitude       6 non-null      float64
# ...

# %%
df.dtypes
# Out:
# _id               object
# index              int64
# guid              object
# isActive            bool
# balance           object
# picture           object
# age                int64
# eyeColor          object
# name              object
# gender            object
# company           object
# email             object
# phone             object
# address           object
# about             object
# registered        object
# latitude         float64
# longitude        float64
# tags              object
# friends           object
# greeting          object
# favoriteFruit     object
# dtype: object

# %%
df.columns
# Out:
# Index(['_id', 'index', 'guid', 'isActive', 'balance', 'picture', 'age',
#        'eyeColor', 'name', 'gender', 'company', 'email', 'phone', 'address',
#        'about', 'registered', 'latitude', 'longitude', 'tags', 'friends',
#        'greeting', 'favoriteFruit'],
#       dtype='object')

# %%
df.age.value_counts()
# Out:
# 20    1
# 22    1
# 40    1
# 29    1
# 33    1
# 23    1
# Name: age, dtype: int64

# %%
df.isnull().sum()
# Out:
# _id              0
# index            0
# guid             0
# isActive         0
# balance          0
# picture          0
# age              0
# eyeColor         0
# name             0
# gender           0
# company          0
# email            0
# phone            0
# address          0
# about            0
# registered       0
# latitude         0
# longitude        0
# tags             0
# friends          0
# greeting         0
# favoriteFruit    0
# dtype: int64

# %%
df[['name','balance']].sum
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of                  name    balance
# 0         Grace Berry  $3,806.93
# 1      Hilary Sellers  $3,330.01
# 2      Sherri Gilbert  $1,619.46
# 3  Caldwell Patterson  $3,334.12
# 4      Head Mcconnell  $1,368.48
# 5        Albert Lopez  $2,441.66>

# %%
df.plot();

# %%
df.corr()
# Out:
#               index  isActive       age  latitude  longitude
# index      1.000000  0.097590  0.257552  0.093354   0.239425
# isActive   0.097590  1.000000  0.071328  0.993446  -0.273873
# age        0.257552  0.071328  1.000000 -0.002530  -0.570790
# latitude   0.093354  0.993446 -0.002530  1.000000  -0.274041
# longitude  0.239425 -0.273873 -0.570790 -0.274041   1.000000

# %%
df.friends
# Out:
# 0    [{'id': 0, 'name': 'Small Pena'}, {'id': 1, 'n...
# 1    [{'id': 0, 'name': 'Spears Smith'}, {'id': 1, ...
# 2    [{'id': 0, 'name': 'Sexton Watts'}, {'id': 1, ...
# 3    [{'id': 0, 'name': 'Anne Holcomb'}, {'id': 1, ...
# 4    [{'id': 0, 'name': 'Elnora Peck'}, {'id': 1, '...
# 5    [{'id': 0, 'name': 'Candice Moreno'}, {'id': 1...
# Name: friends, dtype: object

# %%
df[['greeting','name']]
# Out:
#                                             greeting                name
# 0    Hello, Grace Berry! You have 1 unread messages.         Grace Berry
# 1  Hello, Hilary Sellers! You have 4 unread messa...      Hilary Sellers
# 2  Hello, Sherri Gilbert! You have 1 unread messa...      Sherri Gilbert
# 3  Hello, Caldwell Patterson! You have 6 unread m...  Caldwell Patterson
# 4  Hello, Head Mcconnell! You have 5 unread messa...      Head Mcconnell
# 5   Hello, Albert Lopez! You have 2 unread messages.        Albert Lopez

# %%
df.sort_values(by='name')
# Out:
#                         _id  index                                  guid  \
# 5  5c0a28d749ce43912931715e      5  1d4dcbcd-c5b7-45a8-9650-82d7f98305c6
# 3  5c0a28d76b5e8859a754cb4f      3  d2c4b1eb-2974-463a-b288-d1dae5dec187
# 0  5c0a28d7a647437fd3d3a6aa      0  832f1af4-fb18-4ba8-b032-f4cbf343dbe9
# 4  5c0a28d7ebb99c08e2288c76      4  df0b59ed-2e81-43f1-9ae0-16f138e738be
# 1  5c0a28d780f6278b11586ab1      1  4306cb37-9506-48c2-8ccf-e69a063589ee
# 2  5c0a28d722e2e29d9bce2b64      2  5019e436-7cc4-48ee-a384-3483131f8ee1
#
#    isActive    balance                    picture  age eyeColor  \
# 5      True  $2,441.66  http://placehold.it/32x32   23    green
# 3     False  $3,334.12  http://placehold.it/32x32   29     blue
# 0     False  $3,806.93  http://placehold.it/32x32   20    green
# 4     False  $1,368.48  http://placehold.it/32x32   33    brown
# 1      True  $3,330.01  http://placehold.it/32x32   22    brown
# 2      True  $1,619.46  http://placehold.it/32x32   40    green
#
# ...

# %%
df.sort_values('name',ascending=False)
# Out:
#                         _id  index                                  guid  \
# 2  5c0a28d722e2e29d9bce2b64      2  5019e436-7cc4-48ee-a384-3483131f8ee1
# 1  5c0a28d780f6278b11586ab1      1  4306cb37-9506-48c2-8ccf-e69a063589ee
# 4  5c0a28d7ebb99c08e2288c76      4  df0b59ed-2e81-43f1-9ae0-16f138e738be
# 0  5c0a28d7a647437fd3d3a6aa      0  832f1af4-fb18-4ba8-b032-f4cbf343dbe9
# 3  5c0a28d76b5e8859a754cb4f      3  d2c4b1eb-2974-463a-b288-d1dae5dec187
# 5  5c0a28d749ce43912931715e      5  1d4dcbcd-c5b7-45a8-9650-82d7f98305c6
#
#    isActive    balance                    picture  age eyeColor  \
# 2      True  $1,619.46  http://placehold.it/32x32   40    green
# 1      True  $3,330.01  http://placehold.it/32x32   22    brown
# 4     False  $1,368.48  http://placehold.it/32x32   33    brown
# 0     False  $3,806.93  http://placehold.it/32x32   20    green
# 3     False  $3,334.12  http://placehold.it/32x32   29     blue
# 5      True  $2,441.66  http://placehold.it/32x32   23    green
#
# ...

# %%
df.pivot_table(index='name',columns='gender',values='age')
# Out:
# gender              female  male
# name
# Albert Lopez           NaN  23.0
# Caldwell Patterson     NaN  29.0
# Grace Berry           20.0   NaN
# Head Mcconnell         NaN  33.0
# Hilary Sellers        22.0   NaN
# Sherri Gilbert        40.0   NaN

# %%
df[df['age']>25]
# Out:
#                         _id  index                                  guid  \
# 2  5c0a28d722e2e29d9bce2b64      2  5019e436-7cc4-48ee-a384-3483131f8ee1
# 3  5c0a28d76b5e8859a754cb4f      3  d2c4b1eb-2974-463a-b288-d1dae5dec187
# 4  5c0a28d7ebb99c08e2288c76      4  df0b59ed-2e81-43f1-9ae0-16f138e738be
#
#    isActive    balance                    picture  age eyeColor  \
# 2      True  $1,619.46  http://placehold.it/32x32   40    green
# 3     False  $3,334.12  http://placehold.it/32x32   29     blue
# 4     False  $1,368.48  http://placehold.it/32x32   33    brown
#
#                  name  gender  ...              phone  \
# 2      Sherri Gilbert  female  ...  +1 (954) 591-2183
# 3  Caldwell Patterson    male  ...  +1 (815) 400-3780
# 4      Head Mcconnell    male  ...  +1 (820) 573-3154
#
#                                              address  \
# 2            347 Seeley Street, Witmer, Kansas, 9369
# 3          178 Stewart Street, Ferney, Wyoming, 9118
# ...

# %%
df.groupby('gender').mean()
# Out:
#         index  isActive        age   latitude  longitude
# gender
# female    1.0  0.666667  27.333333   2.521379  21.327186
# male      4.0  0.333333  28.333333 -32.388159  91.211780

# %%
df['age']=df['age'].astype(str)

# %%
df.head()
# Out:
#                         _id  index                                  guid  \
# 0  5c0a28d7a647437fd3d3a6aa      0  832f1af4-fb18-4ba8-b032-f4cbf343dbe9
# 1  5c0a28d780f6278b11586ab1      1  4306cb37-9506-48c2-8ccf-e69a063589ee
# 2  5c0a28d722e2e29d9bce2b64      2  5019e436-7cc4-48ee-a384-3483131f8ee1
# 3  5c0a28d76b5e8859a754cb4f      3  d2c4b1eb-2974-463a-b288-d1dae5dec187
# 4  5c0a28d7ebb99c08e2288c76      4  df0b59ed-2e81-43f1-9ae0-16f138e738be
#
#    isActive    balance                    picture age eyeColor  \
# 0     False  $3,806.93  http://placehold.it/32x32  20    green
# 1      True  $3,330.01  http://placehold.it/32x32  22    brown
# 2      True  $1,619.46  http://placehold.it/32x32  40    green
# 3     False  $3,334.12  http://placehold.it/32x32  29     blue
# 4     False  $1,368.48  http://placehold.it/32x32  33    brown
#
#                  name  gender  ...              phone  \
# 0         Grace Berry  female  ...  +1 (814) 555-3298
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   _id            6 non-null      object
#  1   index          6 non-null      int64
#  2   guid           6 non-null      object
#  3   isActive       6 non-null      bool
#  4   balance        6 non-null      object
#  5   picture        6 non-null      object
#  6   age            6 non-null      object
#  7   eyeColor       6 non-null      object
#  8   name           6 non-null      object
#  9   gender         6 non-null      object
#  10  company        6 non-null      object
#  11  email          6 non-null      object
#  12  phone          6 non-null      object
#  13  address        6 non-null      object
#  14  about          6 non-null      object
#  15  registered     6 non-null      object
#  16  latitude       6 non-null      float64
# ...

# %%
plt.figure(figsize=(12,6))
plt.title('Latitude of Age')
sns.barplot(x=df.age,y=df['latitude'])
plt.xlabel('Age')
plt.ylabel('Latitude')
plt.legend(['Age','Latitude'],fontsize=12);
